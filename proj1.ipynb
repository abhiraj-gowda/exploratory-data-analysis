# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
da=pd.read_csv("train.csv")
da.head(10)
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0          748.0               2.75                1.0   75.00   24
# 1         1187.0               3.43                1.0  105.00   24
# 2          730.0               3.12                1.0   71.25    0
# 3          671.0               5.63                3.0   90.00    0
# 4          329.0               2.09                1.0   45.00   12
# 5          355.0               1.74                1.0   45.00    0
# 6          453.0               2.22                1.0   52.50    0
# 7         1288.0               5.21                1.0  116.25   36
# 8          134.0               1.48                1.0   33.75    0
# 9          980.0               3.48                1.0   90.00    0
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 1              13.200     142.200              0
# 2              26.625      97.875              1
# ...

# %%
da=sns.load_dataset("tips")
da.to_csv('IRIS explore tips dataset.csv')
da.shape
# Out:
# (244, 7)

# %%
da.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
da.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
data=pd.read_csv("IRIS explore tips dataset.csv")
data=data.drop(columns=["Unnamed: 0"])
da=pd.DataFrame(data)
# numeric_columns = data.select_dtypes(include=['int64', 'float64']).columns
data = data.drop(columns=data.select_dtypes(include=['object']).columns)
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
numeric_columns = data.select_dtypes(include=['int64', 'float64'])
numeric_columns
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
type(data.corr())
# Out:
# pandas.core.frame.DataFrame

# %%
# plt.subplot(3,2,1)
# sns.heatmap(data.corr())
# # plt.subplot(3,2,2)
# sns.heatmap(data.corr())
# # plt.subplot(3,2,3)
sns.heatmap(data.corr())
# plt.subplot(3,2,4)
sns.jointplot(x='tip',y='total_bill',data=data,kind='hex')
# plt.subplot(3,2,5)
sns.jointplot(x="tip",y="total_bill",data=data,kind='reg')

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind='hex') # here "hex" gives hexagonal dotted plot with histogram at corners

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind='reg')# here "reg" gives dotted plot  with histogram at corners and reggretion lines over both of them.

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind='scatter')# and this for simple scatter plot

# %%
sns.pairplot(data)

# %%
sns.pairplot(da,hue='sex') # here i've taken third feature in consideration 
                            # it doesn't make 3D plot instard colored marker are used

# %%
da['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
da['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
plt.hist(da['tip'])
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(data['tip'],kde=True,bins=10)# kde= kernal density estimation(its the line over the histogram)
                                   # bins= difference b/t the co-ordinates in X-axis
# Out:
# C:\Users\abhiraj gowda\AppData\Local\Temp\ipykernel_13196\935321903.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['tip'],kde=True,bins=10)# kde= kernal density estimation(its the line over the histogram)
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # <b> categorical plot <hr>
# *  ## count plot

# %%
sns.countplot('sex')
# Out:
# <Axes: xlabel='count'>

# %%
da
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
